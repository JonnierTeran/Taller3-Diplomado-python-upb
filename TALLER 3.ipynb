# %% [markdown]
# # TALLER N3 DIPLOMADO DE PYTHON APLICADO A LA INGENIERIA UPB
#
# ## ESTUDIANTES:
#
# ##### ESTUDIANTE 1:
# #### NOMBRE:Jonnier Andres Teran Morales
# * ID No. 502195
# * id: 1003064599
# * Correo= Jonnier.teran@upb.edu.co
# * Cel: 3245644212
#
# ##### ESTUDIANTE 2:
# #### NOMBRE:Gabriela Torres Ramos
# * ID No.502193
# * id: 1001070935
# * Correo= gabriela.torresr@upb.edu.co
# * Cel: 3234708201
#
# ##### Descripcion:
# ###### Nuestro modelo de negocio esta basado en llevar un analisis de las Salas de cine que estas disponibles, teniendo en cuenta que cada una de ellas tendra un valor diferente, en nuestro caso tenemos una sala BASIC, Con capacidad para 4 personas y tiene un valor de 40000 por cada pelicula vista, tambien tenemos una sala MEDIUM que tiene una capacidad para 10 personas y tiene un valor de 80000 por cada pelicula vista y tambien tenemos una sala PREMIUM con capacidad para 15 personas y con un valor de 120000, ahora bien nuestro calculo para el valor total esta basado en el valor de la sala elegida por pelicula vista, y en los alimentos que escojan del menu teniendo en cuenta tambien las unidades de alimentos que esten incluidas en el pedido, ademas de darle la libertad al usuario de elegir la pelicula deseada entre la oferta disponible.
#
# Contamos con un menu principal que nos permite:
# * generar un alquiler para una sala y obtener la factura (aqui podemos elegir la sala deseada, Elegir Alimentos en el menu, Elegir la cantidad de Pedidos en el menú, Elegir la Pelicula Deseada y obtener una facura donde observamos Nuestro Nombre, Productos Adquiridos, cantidad, pelicula elegida y el valor total a pagar por el servicio en CINEPYTHON
# * Visualizar las salas disponibles
# * Visualizar Las Comidas Disponibles
# * Visualizar Peliculas Disponibles
# * Una Opcion para salir o finalizar la ejecucion del programa

# %%
#Se define la clase
class Cine:
    #definimos las variables

    Bienvenida="""
    CINEPYTHON

    Sea Bienvenido al mejor autoservicio de alquiler de salas de cine para que pueda disfrutar de un momento agradable:

    Selecciones la Opcion Deseada:

    1: Alquiler de Salas de Cine
    2: Visualizar Salas Disponibles
    3: Visualizar Comidas Disponibles
    4: Visualizar Peliculas Disponibles
    5: Salir
    """
    salas = { "1": {'BASIC capacidad': 4, 'valor por Pelicula': 40000},  "2": {'MEIDIUM capacidad': 10, 'valor por Pelicula': 80000}, "3": {'PREMINUM capacidad': 15, 'valor por Pelicula': 120000}}
    Peliculas=["SPIDERMAN","RAPIDOS Y FURIOSOS 7", "LOS INCREIBLES", "LA CASA DE PAPEL"]
    menu = {"1":{'hot dog': "", 'valor': 8000}, "2":{'Hamburguesa': "", 'valor': 16000}, "3":{'Pizza': "", 'valor': 20000}, 4:{'plato de la casa': "", 'valor': 30000}}
    Nombre=""

    #Creamos el metodo constructor
    def __init__(Bienvenida,salas,Peliculas,menu,Nombre):
        Bienvenida = Bienvenida
        salas = salas
        Peliculas = Peliculas
        menu = menu
        Nombre = Nombre
        
    
    #Metodos Accesores
    def get(Bienvenida):
        return Bienvenida
    def get(salas):
        return salas
    def get(Peliculas):
        return Peliculas
    def get(menu):
        return menu
    def get(Nombre):
        return Nombre


    #Metodos
    print(Bienvenida)
    
    Cond = True
    while Cond:
        Opcion = int(input("\nSeleccione una opción:"))
        if Opcion == 1:
            print("BIENVENIDO AL ALQUILER DE SALAS DE CINE: \n")
            Cond = False
            Nombre = input("Digite su nombre por favor: ")
            print("Las Salas de Cine Disponibles son: ")
            for i in salas:
                print(i + str(salas[i]))
            Sa= input("Cual sala desea Elegir?: ")
            Op2= int(input("""Desea usted tomar algo del menu de CINEPYTHON? 
1- SI \n""" ))
            if Op2 ==1:
                    print("EL MENU DEL DIA ES: \n")
                    menu2= menu.items()
                    for key,value in menu2:
                        print(f" {key}{value}")
                    m=input("Seleccione el plato deseado: ")
                    um= input("Indique la cantidad que desea (Unidades)")
                    print("Menu Asignado, sigamos con las peliculas \n")
            else:
                print("Error, Ingrese un valor valido, vuelva a intentar")
            print("Las Peliculas Disponibles son: \n")
            c = 1
            for i in Peliculas:
                print(str(c)+"-"+i)
                c+=1
            pe= int(input("ingrese La Pelicula deseada: "))
            p= pe-1
            print("\n\n\n")
            total1=salas[Sa]['valor por Pelicula']
            total2=menu[m]['valor'] * int(um)
            total3= int(total1) + int(total2)
            print("FACTURA GENERADA POR LOS SERVICIOS DE CINEPYTHON \n USUARIO: " +Nombre +"\n Servicios Adquiridos: \n La sala elegida es:  "+ str(salas[Sa]) +  "\n El menu Elegido es:  "+ str(menu[m]) +"\n Cantidad elegida del menu: "+ str(um)+"\n La Pelicula Elegida es: " +str(Peliculas[p]) +"\n Valor Total: "+str(total3))
        
        elif Opcion ==2:
            print("LAS SALAS DISPONIBLES SON: \n")
            for i in salas:
                    print(i + str(salas[i]))
            
        elif Opcion ==3:
            print("EL MENU DEL DIA ES: \n")
            menu3= menu.items()
            for key,value in menu3:
                print(f" {key}{value}")
        elif Opcion ==4:
            print("Las Peliculas Disponibles son: \n")
            for i in Peliculas:
                print(i)
        elif Opcion == 5:
            print("Muchas gracias por visitarnos, te esperamos pronto. \n")
            Cond = False
        else:
            print("\nComando ingresado no reconocido. Por favor, ingresa una opción válida.\n")
# Out:
#     CINEPYTHON
#
#     Sea Bienvenido al mejor autoservicio de alquiler de salas de cine para que pueda disfrutar de un momento agradable:
#
#     Selecciones la Opcion Deseada:
#
#     1: Alquiler de Salas de Cine
#     2: Visualizar Salas Disponibles
#     3: Visualizar Comidas Disponibles
#     4: Visualizar Peliculas Disponibles
#     5: Salir
#
#
# Seleccione una opción:1
# BIENVENIDO AL ALQUILER DE SALAS DE CINE:
#
# Digite su nombre por favor: Jonnier T
# Las Salas de Cine Disponibles son:
# 1{'BASIC capacidad': 4, 'valor por Pelicula': 40000}
# 2{'MEIDIUM capacidad': 10, 'valor por Pelicula': 80000}
# 3{'PREMINUM capacidad': 15, 'valor por Pelicula': 120000}
# Cual sala desea Elegir?: 3
# Desea usted tomar algo del menu de CINEPYTHON?
# 1- SI
# 1
# EL MENU DEL DIA ES:
#
#  1{'hot dog': '', 'valor': 8000}
#  2{'Hamburguesa': '', 'valor': 16000}
#  3{'Pizza': '', 'valor': 20000}
#  4{'plato de la casa': '', 'valor': 30000}
# Seleccione el plato deseado: 3
# ...
